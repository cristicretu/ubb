# %%
# !pip install deepeval
# !pip install rouge-score
# !pip install evaluate
# Out:
# Requirement already satisfied: deepeval in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (3.9.6)
# Requirement already satisfied: aiohttp in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (3.12.15)
# Requirement already satisfied: click<8.4.0,>=8.0.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (8.3.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.67.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (1.67.1)
# Requirement already satisfied: jinja2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (3.1.6)
# Requirement already satisfied: nest_asyncio in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (1.6.0)
# Requirement already satisfied: openai in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (2.30.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.24.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.24.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (1.40.0)
# Requirement already satisfied: portalocker in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (3.2.0)
# Requirement already satisfied: posthog<6.0.0,>=5.4.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (5.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.7 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (2.12.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (2.13.1)
# Requirement already satisfied: pyfiglet in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (1.0.4)
# Requirement already satisfied: pytest in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (9.0.3)
# Requirement already satisfied: pytest-asyncio in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (1.3.0)
# Requirement already satisfied: pytest-repeat in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (0.9.4)
# Requirement already satisfied: pytest-rerunfailures in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (16.1)
# Requirement already satisfied: pytest-xdist in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (3.8.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.1.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=13.6.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (14.3.3)
# Requirement already satisfied: sentry-sdk in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (2.57.0)
# Requirement already satisfied: setuptools in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (78.1.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (0.9.0)
# Requirement already satisfied: tenacity<=10.0.0,>=8.0.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (9.1.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (4.67.3)
# Requirement already satisfied: typer<1.0.0,>=0.9 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (0.24.1)
# Requirement already satisfied: wheel in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from deepeval) (0.45.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.24.0->deepeval) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.24.0->deepeval) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.24.0->deepeval) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from opentelemetry-sdk<2.0.0,>=1.24.0->deepeval) (0.61b0)
# Requirement already satisfied: six>=1.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from posthog<6.0.0,>=5.4.0->deepeval) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from posthog<6.0.0,>=5.4.0->deepeval) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from posthog<6.0.0,>=5.4.0->deepeval) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from posthog<6.0.0,>=5.4.0->deepeval) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.11.7->deepeval) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.11.7->deepeval) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.11.7->deepeval) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->deepeval) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->deepeval) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->deepeval) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->deepeval) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from rich<15.0.0,>=13.6.0->deepeval) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from rich<15.0.0,>=13.6.0->deepeval) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from typer<1.0.0,>=0.9->deepeval) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from typer<1.0.0,>=0.9->deepeval) (0.0.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.6.0->deepeval) (0.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp->deepeval) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp->deepeval) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp->deepeval) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp->deepeval) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp->deepeval) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp->deepeval) (0.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp->deepeval) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from jinja2->deepeval) (2.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from openai->deepeval) (4.12.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from openai->deepeval) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from openai->deepeval) (0.12.0)
# Requirement already satisfied: sniffio in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from openai->deepeval) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai->deepeval) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->deepeval) (0.16.0)
# Requirement already satisfied: iniconfig>=1.0.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pytest->deepeval) (2.3.0)
# Requirement already satisfied: packaging>=22 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pytest->deepeval) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pytest->deepeval) (1.6.0)
# Requirement already satisfied: execnet>=2.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pytest-xdist->deepeval) (2.1.2)
# Requirement already satisfied: rouge-score in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (0.1.2)
# Requirement already satisfied: absl-py in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from rouge-score) (2.4.0)
# Requirement already satisfied: nltk in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from rouge-score) (3.9.2)
# Requirement already satisfied: numpy in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from nltk->rouge-score) (8.3.1)
# Requirement already satisfied: joblib in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from nltk->rouge-score) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from nltk->rouge-score) (2025.9.18)
# Requirement already satisfied: tqdm in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from nltk->rouge-score) (4.67.3)
# Requirement already satisfied: evaluate in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (2.3.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (0.36.2)
# Requirement already satisfied: packaging in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from evaluate) (26.0)
# Requirement already satisfied: filelock in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (3.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (1.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)

# %% [markdown]
# # Classical NLP testing and LLM-judge testing with Deepeval
#
# ## https://github.com/confident-ai/deepeval

# %%
from rouge_score import rouge_scorer
import evaluate

# expected = "ana are mere, tu ce ai?"
# predicted = "are ana mere"

predicted = "ana are mere  tu ce ai"
expected = "are ana mere tu ce ai"

# ROUGE
rouge = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
rouge_scores = rouge.score(expected, predicted)

print("ROUGE-1 F1:", rouge_scores["rouge1"].fmeasure)
print("ROUGE-L F1:", rouge_scores["rougeL"].fmeasure)

# BLEU
bleu = evaluate.load("bleu")
bleu_result = bleu.compute(predictions=[predicted], references=[[expected]])

print("BLEU score:", bleu_result["bleu"])
# Out:
# ROUGE-1 F1: 1.0
# ROUGE-L F1: 0.8333333333333334
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# BLEU score: 0.5623413251903491

# %% [markdown]
# ### We will set Deepeval to use as LLM-judge a locally hosted LLM
#
# #### Option 1: with LMStudio

# %%
### YOU NEED TO HAVE LMSTUDIO STARTED AND ONE MODEL LOADED
### REPLACE THE MODEL WITH THE ONE THAT YOU LOADED

# !deepeval set-local-model --model="qwen/qwen3.5-9b" --base-url="http://localhost:1234/v1/"
# Out:
# 🙌 Congratulations! You're now using a local model `qwen/qwen3.5-9b` for all
# evals that require an LLM.

# %% [markdown]
# #### Option 2, create a custom LLM handler (through transformers):
#
# #### https://docs.confident-ai.com/guides/guides-using-custom-llms

# %%
from deepeval import assert_test
from deepeval.metrics import GEval
from deepeval.test_case import LLMTestCase, LLMTestCaseParams

def test_case():
    correctness_metric = GEval(
        name="Correctness",
        criteria="Determine if the 'actual output' is correct based on the 'expected output'.",
        evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
        threshold=0.5
    )
    test_case = LLMTestCase(
        input="What if these shoes don't fit?",
        actual_output="You have 30 days to get a full refund at no extra cost.",
        expected_output="We offer a 30-day full refund at no extra costs.",
        retrieval_context=["All customers are eligible for a 30 day full refund at no extra costs."]
    )
    assert_test(test_case, [correctness_metric])

test_case()
# Out:
# ---------------------------------------------------------------------------
# DeepEvalError                             Traceback (most recent call last)
# Cell In[8], line 20
#      12     test_case = LLMTestCase(
#      13         input="What if these shoes don't fit?",
#      14         actual_output="You have 30 days to get a full refund at no extra cost.",
#      15         expected_output="We offer a 30-day full refund at no extra costs.",
#      16         retrieval_context=["All customers are eligible for a 30 day full refund at no extra costs."]
#      17     )
#      18     assert_test(test_case, [correctness_metric])
# ---> 20 test_case()
#
# Cell In[8], line 6, in test_case()
#       5 def test_case():
# ----> 6     correctness_metric = GEval(
#       7         name="Correctness",
#       8         criteria="Determine if the 'actual output' is correct based on the 'expected output'.",
#       9         evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
#      10         threshold=0.5
#      11     )
#      12     test_case = LLMTestCase(
#      13         input="What if these shoes don't fit?",
#      14         actual_output="You have 30 days to get a full refund at no extra cost.",
#      15         expected_output="We offer a 30-day full refund at no extra costs.",
#      16         retrieval_context=["All customers are eligible for a 30 day full refund at no extra costs."]
#      17     )
#      18     assert_test(test_case, [correctness_metric])
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/deepeval/metrics/g_eval/g_eval.py:67, in GEval.__init__(self, name, evaluation_params, criteria, evaluation_steps, rubric, model, threshold, top_logprobs, async_mode, strict_mode, verbose_mode, evaluation_template, _include_g_eval_suffix)
#      65 self.score_range = get_score_range(self.rubric)
#      66 self.score_range_span = self.score_range[1] - self.score_range[0]
# ---> 67 self.model, self.using_native_model = initialize_model(model)
#      68 self.evaluation_model = self.model.get_model_name()
#      69 self.evaluation_steps = (
#      70     evaluation_steps
#      71     if evaluation_steps and len(evaluation_steps) > 0
#      72     else None
#      73 )
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/deepeval/metrics/utils.py:597, in initialize_model(model)
#     595     return OllamaModel(model=model), True
#     596 elif should_use_local_model():
# --> 597     return LocalModel(model=model), True
#     598 elif should_use_azure_openai():
#     599     return AzureOpenAIModel(model=model), True
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/deepeval/models/llms/local_model.py:81, in LocalModel.__init__(self, model, api_key, base_url, temperature, format, generation_kwargs, **kwargs)
#      78 self.generation_kwargs = dict(generation_kwargs or {})
#      79 self.generation_kwargs.pop("temperature", None)
# ---> 81 super().__init__(model)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/deepeval/models/base_model.py:48, in DeepEvalBaseLLM.__init__(self, model, *args, **kwargs)
#      46 def __init__(self, model: Optional[str] = None, *args, **kwargs):
#      47     self.name = parse_model_name(model)
# ---> 48     self.model = self.load_model()
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/deepeval/models/llms/local_model.py:208, in LocalModel.load_model(self, async_mode)
#     206 def load_model(self, async_mode: bool = False):
#     207     if not async_mode:
# --> 208         return self._build_client(OpenAI)
#     209     return self._build_client(AsyncOpenAI)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/deepeval/models/llms/local_model.py:222, in LocalModel._build_client(self, cls)
#     221 def _build_client(self, cls):
# --> 222     local_model_api_key = require_secret_api_key(
#     223         self.local_model_api_key,
#     224         provider_label="Local",
#     225         env_var_name="LOCAL_MODEL_API_KEY",
#     226         param_hint="`api_key` to LocalModel(...)",
#     227     )
#     229     kw = dict(
#     230         api_key=local_model_api_key,
#     231         base_url=self.base_url,
#     232         **self._client_kwargs(),
#     233     )
#     234     try:
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/deepeval/models/utils.py:67, in require_secret_api_key(secret, provider_label, env_var_name, param_hint)
#      47 """
#      48 Normalize and validate a provider API key stored as a SecretStr.
#      49
#    (...)     64     DeepEvalError: if the key is missing or empty.
#      65 """
#      66 if secret is None:
# ---> 67     raise DeepEvalError(
#      68         f"{provider_label} API key is not configured. "
#      69         f"Set {env_var_name} in your environment or pass "
#      70         f"{param_hint}."
#      71     )
#      73 api_key = secret.get_secret_value()
#      74 if not api_key:
#
# DeepEvalError: Local API key is not configured. Set LOCAL_MODEL_API_KEY in your environment or pass `api_key` to LocalModel(...).

# %% [markdown]
# ## Implement other metrics
#
#
# ### https://docs.confident-ai.com/docs/metrics-introduction#using-local-llm-models

# %%
## ....
