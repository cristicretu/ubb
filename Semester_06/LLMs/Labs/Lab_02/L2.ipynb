# %%
# %pip install transformers langchain torch langchain-community langchain-huggingface
% pip install -U "typing_extensions>=4.14.0"
# Out:
# Requirement already satisfied: transformers in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (4.48.3)
# Requirement already satisfied: langchain in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (1.2.12)
# Requirement already satisfied: torch in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: langchain-community in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: langchain-huggingface in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: filelock in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (3.25.2)
# Collecting huggingface-hub<1.0,>=0.24.0 (from transformers)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.15.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain) (1.2.18)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.16)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: setuptools in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from torch) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-community) (1.0.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/giga/miniconda3/envs/ml/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.6.0
#     Uninstalling huggingface_hub-1.6.0:
#       Successfully uninstalled huggingface_hub-1.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2026.2.0 which is incompatible.
# iopaint 1.6.0 requires huggingface-hub==0.25.2, but you have huggingface-hub 0.36.2 which is incompatible.
# Successfully installed huggingface-hub-0.36.2
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%` not found.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from transformers import T5Tokenizer, T5ForConditionalGeneration
from langchain_huggingface import HuggingFacePipeline

model_name = "microsoft/phi-4"

if model_name.startswith("t5"):
    tokenizer = T5Tokenizer.from_pretrained(model_name)
    model = T5ForConditionalGeneration.from_pretrained(model_name)

    hf_pipeline = pipeline(
        "text2text-generation",
        model=model,
        tokenizer=tokenizer,
        max_length=512,
        max_new_tokens=50,
        truncation=True
    )
else:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)

    tokenizer.pad_token = tokenizer.eos_token

    hf_pipeline = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_length=512,
        truncation=True
    )

llm = HuggingFacePipeline(pipeline=hf_pipeline)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/95.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/802 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/4.77G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/4.77G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
### Try this for gpt2 and t5-small
prompt = "How are you?"

output = llm(prompt)

output

# %%
from langchain.prompts import PromptTemplate, ChatPromptTemplate

template = PromptTemplate(
    input_variables=["text"],
    template="translate English to French: {text}"
)

### Try this for gpt2 and t5-small
prompt_text = template.format(text="How are you?")

response = llm(prompt_text)

response

# %%
template_string = """You be tasked with takin' the followin' text \
and transformin' it into a joke in the style of {style}. \
Make sure it stays true to the humor and tone of the given style. \
If the text ain't naturally a joke, twist it into somethin' funny! 

text: ```{text}```
"""

# %%
prompt_template = PromptTemplate.from_template(template_string)

prompt_template

# %%
prompt_template.input_variables

# %%
prompt_style = """pirate"""

prompt_input = """Why do programmers prefer dark mode?"""

# %%
message = prompt_template.format(
                    style=customer_style,
                    text=customer_email)

response = llm(message)

response

# %%
from langchain.chains import LLMChain

prompt = ChatPromptTemplate.from_template(
    "Tell a joke about {topic} in the style of {style}."
)

chain = LLMChain(llm=llm, prompt=prompt)

# Example Input
topic = "why pirates love gold"
style = "pirate"

chain.invoke({"topic": topic, "style": style})

# %%
## SequentialChain

from langchain.chains import SequentialChain

first_prompt = ChatPromptTemplate.from_template(
    "Translate the following review to english:"
    "\n\n{Review}"
)

chain_one = LLMChain(llm=llm, prompt=first_prompt, 
                     output_key="English_Review"
                    )
second_prompt = ChatPromptTemplate.from_template(
    "Can you summarize the following review in 1 sentence:"
    "\n\n{English_Review}"
)

chain_two = LLMChain(llm=llm, prompt=second_prompt, 
                     output_key="summary"
                    )

third_prompt = ChatPromptTemplate.from_template(
    "What language is the following review:\n\n{Review}"
)

chain_three = LLMChain(llm=llm, prompt=third_prompt,
                       output_key="language"
                      )

fourth_prompt = ChatPromptTemplate.from_template(
    "Write a follow up response to the following "
    "summary in the specified language:"
    "\n\nSummary: {summary}\n\nLanguage: {language}"
)

chain_four = LLMChain(llm=llm, prompt=fourth_prompt,
                      output_key="followup_message"
                     )

overall_chain = SequentialChain(
    chains=[chain_one, chain_two, chain_three, chain_four],
    input_variables=["Review"],
    output_variables=["English_Review", "summary","followup_message"],
    verbose=True
)

review = "Je trouve le goût médiocre. La mousse ne tient pas, c'est bizarre. J'achète les mêmes dans le commerce et le goût est bien meilleur...\nVieux lot ou contrefaçon !?"

overall_chain(review)

# %%
## Router Chain
from langchain.chains.router import MultiPromptChain
from langchain.chains.router.llm_router import LLMRouterChain, RouterOutputParser

## ....
