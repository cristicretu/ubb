# %% [markdown]
# # Modeling and solving search problems
#
# Consider the following river crossing puzzle:
#
# ## Jealous Husbands Problem with an Island
#
# There are n couples: $(𝐻_1,𝑊_1)$, $(𝐻_2,𝑊_2)$, …, $(𝐻_𝑛,𝑊_𝑛)$  where $𝐻_𝑖$ is husband $𝑖$ and $𝑊_𝑖$ is wife $𝑖$.
#
# They need to cross from the left bank of a river to the right bank.
#
# There is a boat that can carry at most two people at a time.
#
# Important: There is an island midway between the left and right banks. The boat can stop at the island.
#
# Rules:
#
# 1. Jealousy constraint: No wife may ever be in the presence of another husband (on any shore or the island or in the boat) unless her own husband is also present. Otherwise, fights (and failures) occur.
#
# 2. The boat needs at least one person to operate (no remote-controlled trips).
#
# 3. The boat can travel between:
#
#             Left bank ↔ Island
#
#             Island ↔ Right bank
#
# 4. All people, including the boat, start at the left bank.
#
# Goal: get everyone (husbands and wives) safely to the right bank, obeying all the rules.
#
#
# ## Tasks:
#
# 1. Put the problem in a form of a search tree: root, nodes, solution and rules for constructing the childrens.
# 2. Solve it usinh a classic DFS
# 3. Solve it using a classic Back-tracking.
# 4. Solve it using the A* method.

# %%
class State:
    def __init__(self, husbands, wives, boat):
        self.husbands = husbands.copy()  
        self.wives = wives.copy()        
        self.boat = boat  #(0=left, 1=island, 2=right)
    
    def __eq__(self, other):
        return (self.husbands == other.husbands and 
                self.wives == other.wives and 
                self.boat == other.boat)
    
    def __hash__(self):
        return hash((tuple(self.husbands), tuple(self.wives), self.boat))

    def __lt__(self, other):
        return self.boat < other.boat
    
    def __le__(self, other):
        return self.boat <= other.boat
    
    def __gt__(self, other):
        return self.boat > other.boat
    
    
    def is_valid(self):
        for location in [0, 1, 2]: 
            wives_here = [i for i, loc in enumerate(self.wives) if loc == location]
            if not wives_here:
                continue
            
            husbands_here = [i for i, loc in enumerate(self.husbands) if loc == location]
            
            for wife_idx in wives_here:
                if self.husbands[wife_idx] != location:
                    if husbands_here:
                        return False
        
        return True
    
    def is_goal(self, n):
        return all(h == 2 for h in self.husbands) and all(w == 2 for w in self.wives)
    
    def __str__(self):
        locations = ["Left", "Island", "Right"]
        boat_loc = locations[self.boat]
        
        result = f"Boat: {boat_loc}\n"
        for i in range(len(self.husbands)):
            result += f"Couple {i}: Husband at {locations[self.husbands[i]]}, Wife at {locations[self.wives[i]]}\n"
        return result

# %%
def get_successors(state, n):
    successors = []
    
    people_at_boat = []
    for i in range(n):
        if state.husbands[i] == state.boat:
            people_at_boat.append(('H', i))
        if state.wives[i] == state.boat:
            people_at_boat.append(('W', i))
    
    if state.boat == 0: 
        destinations = [1]  
    elif state.boat == 1:  
        destinations = [0, 2] 
    else: 
        destinations = [1] 
    
    for destination in destinations:
        for person in people_at_boat:
            new_state = move_people(state, [person], destination)
            if new_state.is_valid():
                successors.append(new_state)
        
        for i in range(len(people_at_boat)):
            for j in range(i+1, len(people_at_boat)):
                new_state = move_people(state, [people_at_boat[i], people_at_boat[j]], destination)
                if new_state.is_valid():
                    successors.append(new_state)
    
    return successors

def move_people(state, people, destination):
    new_husbands = state.husbands.copy()
    new_wives = state.wives.copy()
    
    for person_type, idx in people:
        if person_type == 'H':
            new_husbands[idx] = destination
        else: 
            new_wives[idx] = destination
    
    return State(new_husbands, new_wives, destination)

# %%
from collections import deque
import heapq

# %%
def bkt_solve(n):
    initial_state = State([0] * n, [0] * n, 0)
    
    visited_on_current_path = set()

    def bkt_recursive_helper(current_state, path_history):
        if current_state.is_goal(n):
            return path_history + [current_state]

        visited_on_current_path.add(current_state)

        for successor in get_successors(current_state, n):
            if successor not in visited_on_current_path: 
                result = bkt_recursive_helper(successor, path_history + [current_state])
                
                if result:
                    return result
                
        if current_state in visited_on_current_path: 
            visited_on_current_path.remove(current_state)
        return None

    solution_path = bkt_recursive_helper(initial_state, [])
    
    return solution_path

# %%
def dfs_solve(n, track_visited=True):
    initial_state = State([0] * n, [0] * n, 0)
    visited = set()
    
    def dfs(state, path):
        if state.is_goal(n):
            return path + [state]
        
        visited.add(state)
        
        successors = get_successors(state, n)
        
        def priority_score(s):
            right_bank_count = sum(1 for h in s.husbands if h == 2) + sum(1 for w in s.wives if w == 2)
            return right_bank_count
        
        successors.sort(key=priority_score, reverse=True)
        
        for successor in successors:
            if successor not in visited:
                result = dfs(successor, path + [state])
                if result:
                    return result
        
        if not track_visited:
            visited.remove(state) 
        
        return None
    
    return dfs(initial_state, [])

# %%
def a_star_solve(n):
    
    initial_state = State([0] * n, [0] * n, 0)
    
    def heuristic(state):
        return sum(1 for h in state.husbands if h != 2) + sum(1 for w in state.wives if w != 2)
    
    queue = [(heuristic(initial_state), 0, initial_state, [])]
    visited = {initial_state: 0}  
    while queue:
        _, g, state, path = heapq.heappop(queue)
        
        if state.is_goal(n):
            return path + [state]
        
        for successor in get_successors(state, n):
            new_g = g + 1
            
            if successor not in visited or new_g < visited[successor]:
                visited[successor] = new_g
                f = new_g + heuristic(successor)
                heapq.heappush(queue, (f, new_g, successor, path + [state]))
    
    return None

# %%
def print_solution(path, algorithm_name):
    if not path:
        print(f"No solution found using {algorithm_name}!")
        return
    
    print(f"\n{algorithm_name} solution found in {len(path)-1} moves:")
    
    print("\nInitial state:")
    print(path[0])
    
    for i in range(1, len(path)):
        print(f"\nMove {i}:")
        
        prev, curr = path[i-1], path[i]
        moved_people = []
        
        for j in range(len(prev.husbands)):
            if prev.husbands[j] != curr.husbands[j]:
                moved_people.append(f"Husband {j}")
            if prev.wives[j] != curr.wives[j]:
                moved_people.append(f"Wife {j}")
        
        direction = "→" if prev.boat < curr.boat else "←"
        locations = ["Left", "Island", "Right"]
        print(f"  {', '.join(moved_people)} moved from {locations[prev.boat]} {direction} {locations[curr.boat]}")
        print(curr)

def solve_jealous_husbands(n=3):
    print("BKT:")    
    bkt_solution = bkt_solve(n)
    print_solution(bkt_solution, "BKT")
    
    print("\nDFS")
    dfs_solution = dfs_solve(n)
    print_solution(dfs_solution, "DFS")
    
    print("\nA*")
    astar_solution = a_star_solve(n)
    print_solution(astar_solution, "A*")

# %%
solve_jealous_husbands(3)
# Out:
# BKT:
#
# BKT solution found in 206 moves:
#
# Initial state:
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 1:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 2:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 3:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 4:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 5:
#   Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 6:
#   Husband 1, Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 7:
#   Husband 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 8:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 9:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 10:
#   Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 11:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 12:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 13:
#   Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 14:
#   Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 15:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 16:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 17:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 18:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 19:
#   Wife 1, Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 20:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 21:
#   Wife 0, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 22:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 23:
#   Husband 1, Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 24:
#   Husband 1, Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 25:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 26:
#   Husband 2, Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 27:
#   Husband 1, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 28:
#   Husband 0, Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 29:
#   Husband 0, Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 30:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 31:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 32:
#   Husband 0, Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 33:
#   Husband 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 34:
#   Husband 1, Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 35:
#   Husband 1, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 36:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 37:
#   Husband 0, Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 38:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 39:
#   Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 40:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 41:
#   Husband 1, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 42:
#   Husband 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 43:
#   Husband 0, Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 44:
#   Husband 0, Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 45:
#   Husband 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 46:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 47:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 48:
#   Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 49:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 50:
#   Wife 0, Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 51:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 52:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 53:
#   Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 54:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 55:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 56:
#   Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 57:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 58:
#   Husband 0, Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 59:
#   Husband 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 60:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 61:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 62:
#   Husband 1, Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 63:
#   Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 64:
#   Husband 0, Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 65:
#   Husband 0, Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 66:
#   Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 67:
#   Husband 2, Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 68:
#   Husband 0, Husband 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 69:
#   Husband 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 70:
#   Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 71:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 72:
#   Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 73:
#   Husband 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 74:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 75:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 76:
#   Husband 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 77:
#   Husband 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 78:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 79:
#   Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 80:
#   Husband 1, Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 81:
#   Husband 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 82:
#   Husband 2, Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 83:
#   Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 84:
#   Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 85:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 86:
#   Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 87:
#   Husband 1, Husband 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 88:
#   Husband 1, Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 89:
#   Husband 1, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 90:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 91:
#   Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 92:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 93:
#   Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 94:
#   Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 95:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 96:
#   Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 97:
#   Husband 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 98:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 99:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 100:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 101:
#   Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 102:
#   Husband 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 103:
#   Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 104:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 105:
#   Husband 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 106:
#   Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 107:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 108:
#   Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 109:
#   Husband 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 110:
#   Husband 0, Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 111:
#   Husband 0, Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 112:
#   Husband 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 113:
#   Husband 0, Husband 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 114:
#   Husband 0, Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 115:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 116:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 117:
#   Husband 2, Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 118:
#   Husband 0, Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 119:
#   Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 120:
#   Husband 1, Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 121:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 122:
#   Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 123:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 124:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 125:
#   Husband 0, Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 126:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 127:
#   Husband 1, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 128:
#   Wife 1, Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 129:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 130:
#   Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 131:
#   Husband 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 132:
#   Husband 0, Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 133:
#   Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 134:
#   Husband 1, Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 135:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 136:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 137:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 138:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 139:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 140:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 141:
#   Husband 0, Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 142:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 143:
#   Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 144:
#   Husband 0, Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 145:
#   Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 146:
#   Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 147:
#   Husband 0, Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 148:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 149:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 150:
#   Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 151:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 152:
#   Husband 1, Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 153:
#   Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 154:
#   Husband 0, Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 155:
#   Husband 0, Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 156:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 157:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 158:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 159:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 160:
#   Husband 0, Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 161:
#   Husband 2, Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 162:
#   Husband 1, Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 163:
#   Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 164:
#   Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 165:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 166:
#   Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 167:
#   Husband 0, Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 168:
#   Husband 1, Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 169:
#   Husband 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 170:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 171:
#   Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 172:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 173:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 174:
#   Husband 0, Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 175:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 176:
#   Wife 0, Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 177:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 178:
#   Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 179:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 180:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 181:
#   Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 182:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 183:
#   Husband 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 184:
#   Husband 2, Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 185:
#   Husband 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 186:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 187:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 188:
#   Husband 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 189:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 190:
#   Wife 0, Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 191:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 192:
#   Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 193:
#   Husband 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 194:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 195:
#   Husband 1, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 196:
#   Husband 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 197:
#   Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 198:
#   Wife 1, Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Left
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 199:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 200:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 201:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 202:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Left
#
#
# Move 203:
#   Wife 0, Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 204:
#   Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 205:
#   Husband 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 206:
#   Husband 2, Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# DFS
#
# DFS solution found in 56 moves:
#
# Initial state:
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 1:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 2:
#   Husband 0, Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 3:
#   Husband 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 4:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 5:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 6:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 7:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 8:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 9:
#   Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 10:
#   Husband 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 11:
#   Husband 1, Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 12:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 13:
#   Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 14:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 15:
#   Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 16:
#   Wife 0, Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 17:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 18:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 19:
#   Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 20:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 21:
#   Wife 1, Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 22:
#   Wife 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 23:
#   Wife 0, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 24:
#   Wife 0, Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 25:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 26:
#   Wife 0, Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 27:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 28:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 29:
#   Husband 0, Wife 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 30:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 31:
#   Husband 0, Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 32:
#   Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 33:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 34:
#   Husband 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 35:
#   Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 36:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 37:
#   Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 38:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 39:
#   Husband 0 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 40:
#   Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 41:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 42:
#   Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Left, Wife at Right
#
#
# Move 43:
#   Husband 1, Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 44:
#   Husband 1, Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 45:
#   Husband 1, Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 46:
#   Husband 0, Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 47:
#   Husband 0, Husband 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 48:
#   Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Right
#
#
# Move 49:
#   Wife 2 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Right
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 50:
#   Husband 0, Husband 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 51:
#   Husband 0, Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 52:
#   Husband 0, Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 53:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 54:
#   Wife 0, Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 55:
#   Wife 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 56:
#   Wife 0, Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# A*
#
# A* solution found in 18 moves:
#
# Initial state:
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Left
#
#
# Move 1:
#   Husband 2, Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 2:
#   Husband 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Left
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 3:
#   Wife 0, Wife 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Island
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 4:
#   Wife 0 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Island
# Couple 2: Husband at Left, Wife at Island
#
#
# Move 5:
#   Husband 1, Husband 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Island
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 6:
#   Husband 1, Wife 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 7:
#   Husband 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 8:
#   Husband 1 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Left, Wife at Left
# Couple 1: Husband at Left, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 9:
#   Husband 0, Husband 1 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Island, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 10:
#   Husband 0, Husband 1 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 11:
#   Husband 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 12:
#   Wife 2 moved from Island ← Left
# Boat: Left
# Couple 0: Husband at Island, Wife at Left
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Left
#
#
# Move 13:
#   Wife 0, Wife 2 moved from Left → Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Island, Wife at Island
#
#
# Move 14:
#   Husband 0, Husband 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 15:
#   Wife 1 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Island
# Couple 2: Husband at Right, Wife at Island
#
#
# Move 16:
#   Wife 1, Wife 2 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 17:
#   Husband 0 moved from Right ← Island
# Boat: Island
# Couple 0: Husband at Island, Wife at Island
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
#
#
# Move 18:
#   Husband 0, Wife 0 moved from Island → Right
# Boat: Right
# Couple 0: Husband at Right, Wife at Right
# Couple 1: Husband at Right, Wife at Right
# Couple 2: Husband at Right, Wife at Right
